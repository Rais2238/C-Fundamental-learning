# %% [markdown]
# <a href="https://colab.research.google.com/github/Rais2238/C-Fundamental-learning/blob/main/learn%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
materi pertama tentang pehamanan penggunaan python

# %%
a=2
b=3
c=a+b
print(c)
# Out:
# 5
